# %%
from __future__ import division, unicode_literals, print_function  # for compatibility with Python 2 and 3

import matplotlib as mpl
import matplotlib.pyplot as plt

# change the following to %matplotlib notebook for interactive plotting
# %matplotlib inline

# Optionally, tweak styles.
mpl.rc('figure',  figsize=(10, 6))
mpl.rc('image', cmap='gray')
import cv2
import trackpy as tp
from matplotlib import cm
import plotly.plotly as py
from scipy.fftpack import fft

# %%
import cv2
print(cv2.__version__)
# Out:
# 3.4.0

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series  # for convenience

import pims

# %%
# get the frame number of video
cap = cv2.VideoCapture("reference20fps4Xmagneticnogravity.avi")
length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print( length )
# Out:
# 9350

# %%
frames=pims.Video('reference20fps4Xmagneticnogravity.avi')
# first three minutues
#frames=frames[9300:9300+18000]

# %%
frames=frames[::20]
len(frames)
# Out:
# 468

# %%
w,l,_=frames[1].shape

# %%
new_frame=np.zeros((len(frames),w, l))

# %%
for i in range(len(frames)-1):
    new_frame[i]=cv2.cvtColor(frames[i]-5, cv2.COLOR_BGR2GRAY)
    if i%50==0:
        print(i)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450

# %%
plt.imshow(cv2.cvtColor(frames[1]-5, cv2.COLOR_BGR2GRAY))

# %%
plt.imshow(new_frame[150])

# %%
import trackpy as tp
from matplotlib import cm

# %%
f = tp.locate(new_frame[100],19, invert=True,minmass=1500)

# %%
plt.figure()  # make a new figure
tp.annotate(f, new_frame[100]);

# %%
f.head()
# Out:
#               y            x          mass      size       ecc     signal  \
# 0      8.388156  1457.574184   9348.676823  5.487350  0.013196  64.013062
# 553   77.538137  1339.966065   8679.001715  5.409552  0.038162  64.628572
# 668   81.211715   418.849965  10602.778876  5.304233  0.011603  76.323266
# 762   99.701868   108.921622  10263.940505  5.365491  0.025067  70.475919
# 865  108.111021   820.583874  11007.784594  5.402847  0.006035  73.553470
#
#      raw_mass        ep
# 0     -9874.0  0.013918
# 553   -9664.0  0.013801
# 668  -11804.0  0.015091
# 762  -10379.0  0.014207
# 865  -10358.0  0.014195

# %%
plt.hist(f['mass'])
# Out:
# (array([ 2.,  1.,  2.,  3.,  2.,  1.,  1.,  2.,  7., 10.]),
#  array([ 8070.56987206,  8383.0028546 ,  8695.43583714,  9007.86881968,
#          9320.30180222,  9632.73478476,  9945.1677673 , 10257.60074984,
#         10570.03373238, 10882.46671492, 11194.89969746]),
#  <a list of 10 Patch objects>)

# %%
f = tp.batch( new_frame, 19, invert=True,minmass=1500);
# Out:
# Frame 467: 0 features

# %%
t = tp.link_df(f,200, memory=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-104-51eb8adfa95b> in <module>()
# ----> 1 t = tp.link_df(f,200, memory=10)
#
# /anaconda/lib/python3.6/site-packages/trackpy/linking/linking.py in link(f, search_range, pos_columns, t_column, **kwargs)
#     121     coords_iter = coords_from_df(f, pos_columns, t_column)
#     122     ids = []
# --> 123     for i, _ids in link_iter(coords_iter, search_range, **kwargs):
#     124         ids.extend(_ids)
#     125
#
# /anaconda/lib/python3.6/site-packages/trackpy/linking/linking.py in link_iter(coords_iter, search_range, **kwargs)
#      55
#      56     for t, coords in coords_iter:
# ---> 57         linker.next_level(coords, t)
#      58         yield t, linker.particle_ids
#      59
#
# /anaconda/lib/python3.6/site-packages/trackpy/linking/linking.py in next_level(self, coords, t, extra_data)
#     405         self.subnets = Subnets(prev_hash, self.hash, self.search_range,
#     406                                self.MAX_NEIGHBORS)
# --> 407         spl, dpl = self.assign_links()
#     408         self.apply_links(spl, dpl)
#     409
#
# /anaconda/lib/python3.6/site-packages/trackpy/linking/linking.py in assign_links(self)
#     412         for source_set, dest_set in self.subnets:
#     413             sn_spl, sn_dpl = self.subnet_linker(source_set, dest_set,
# --> 414                                                 self.search_range)
#     415             spl.extend(sn_spl)
#     416             dpl.extend(sn_dpl)
#
# /anaconda/lib/python3.6/site-packages/trackpy/linking/subnetlinker.py in subnet_linker_numba(source_set, dest_set, search_range, **kwargs)
#     445         _s.forward_cands.append((None, search_range))
#     446
# --> 447     sn_spl, sn_dpl = numba_link(source_set, len(dest_set), search_range, **kwargs)
#     448
#     449     for dp in dest_set - set(sn_dpl):
#
# /anaconda/lib/python3.6/site-packages/trackpy/linking/subnetlinker.py in numba_link(s_sn, dest_size, search_range, max_size, diag)
#     228     # In the next line, distsarray is passed in quadrature so that adding distances works.
#     229     loopcount = _numba_subnet_norecur(ncands, candsarray, distsarray**2, cur_assignments, cur_sums,
# --> 230                                     tmp_assignments, best_assignments)
#     231     if diag:
#     232         for dr in dcands:
#
# KeyboardInterrupt:

# %%
t_ref = tp.filter_stubs(t, 50)
# Compare the number of particles in the unfiltered and filtered data.
print('Before:', t_ref['particle'].nunique())
print('After:', t_ref['particle'].nunique())
# Out:
# Before: 0
# After: 0

# %%
#t_L1=t1
plt.figure()
tp.plot_traj(t_ref);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-806e1ff73d77> in <module>()
#       1 #t_L1=t1
#       2 plt.figure()
# ----> 3 tp.plot_traj(t_ref);
#
# /anaconda/lib/python3.6/site-packages/trackpy/plots.py in wrapper(*args, **kwargs)
#      51         legend = kwargs.pop('legend', False)
#      52
# ---> 53         result = func(*args, **kwargs)
#      54
#      55         if legend:
#
# /anaconda/lib/python3.6/site-packages/trackpy/plots.py in plot_traj(traj, colorby, mpp, label, superimpose, cmap, ax, t_column, pos_columns, plot_style, **kwargs)
#     312         pos_columns = ['x', 'y']
#     313     if len(traj) == 0:
# --> 314         raise ValueError("DataFrame of trajectories is empty.")
#     315     _plot_style = dict(linewidth=1)
#     316     _plot_style.update(**_normalize_kwargs(plot_style, 'line2d'))
#
# ValueError: DataFrame of trajectories is empty.

# %%
t_3L1['particle'].replace(1, 27,inplace=True)
# Out:
# /anaconda/lib/python3.6/site-packages/pandas/core/generic.py:4619: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
t_3L2.to_csv("3Lleft02.csv",encoding='utf-8')

# %%
t1=t_L2
posi=t1.loc[t1['particle'] == int(2)][['x','y']]
np.linalg.norm((posi.iloc[1]-posi.iloc[0]).values)
# Out:
# 0.0866166801422936

# %%
# delete particle is not moving
t1=t_3L2
l=list(set(np.sort(t1['particle'].values)))
for i, value in enumerate(l):
    posi=t1.loc[t1['particle'] == int(value)][['x','y']]
    if (np.linalg.norm((posi.iloc[1]-posi.iloc[0]).values))<1:
        t1 = t1[t1.particle!=int(value) ]
t_3L2=t1

# %%
import pandas as pd

# %%
t_reference=pd.read_csv('reference_horinontal.csv')
t_L1=pd.read_csv('Lleft01.csv')
t_L2=pd.read_csv('Lleft02.csv')
t_3L1=pd.read_csv('3Lleft01.csv')
t_3L2=pd.read_csv('3Lleft02.csv')

# %%
def velocity(input):
    t1=input
    fps=2
    scale=0.87
    velocity_me=[]
    for i in set(t1['particle'].values):

        net=np.linalg.norm(np.diff(t1.loc[t1['particle']==i][['x','y']].values,axis=0),axis=1)* fps*scale
        net2=[np.sum(net[:j])/fps for j in range(1,len(net))]
        #realframes=np.argmax(np.gradient(net2, 2)<0.09)
        #if  realframes==0:
           # realframes=t1['frame'].max()
        realframes=t1['frame'].max()
        distance=net2[-1]
        velocity_me.append(distance/((realframes+1)/fps))
    return [net,net2, velocity_me]

# %%
# Out:
# array([[483.01293019, 482.95445216, 483.62708436, ..., 447.90756657,
#         447.73061682, 447.58415671],
#        [424.42522124, 416.55810771, 408.42550567, ..., 555.66287496,
#         547.71691937, 539.53294957]])

# %%
plt.figure()
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.3)
ax1=plt.subplot(221)
plt.plot(t_reference[['x']].values*scale,t_reference[['y']].values*scale,color='purple',alpha=0.5,linewidth=0.3)
plt.xlabel("x($\mu m$) ")
plt.ylabel("y($\mu m$) ")
ax1.set_aspect(1)

ax2=plt.subplot(222)
plt.hist(velocity(t_reference)[0],20, density=True, facecolor='purple',edgecolor='orange', alpha=1)
plt.xlabel("velocity,$\mu m/s$ ")
plt.ylabel("density")
plt.xlim(12,15.5)

ax3=plt.subplot(223)
plt.plot(np.arange(3600)/2,velocity(t_reference)[0],color='purple',alpha=0.5,linewidth=0.3)
plt.axhline(y=velocity(t_reference)[2], linewidth=2, color="orange",linestyle='dashed')
plt.xlabel("$Time,s$")
plt.ylabel("velocity,$\mu m/s$ ")
#plt.xlim(12,15.5)

N=len(velocity(t_reference)[0])
sampling_rate =2
T = 1/sampling_rate 
x = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
yr = fft( velocity(t_reference)[0]) # "raw" FFT with both + and - frequencies
y = 2/N * np.abs(yr[0:np.int(N/2)]) # positive freqs only


ax3=plt.subplot(224)
plt.plot(x, y,color='black')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Vibration (g)')
plt.xlim(0,0.04)
plt.ylim(0,0.4)

#plt.xlim(12,15.5)
# Out:
# (0, 0.4)

# %%
plt.figure()
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.3)
ax1=plt.subplot(221)
plt.plot(t_L1[['x']].values*scale,t_L1[['y']].values*scale,color='purple',alpha=0.5,linewidth=0.3)
plt.xlabel("x($\mu m$) ")
plt.ylabel("y($\mu m$) ")
ax1.set_aspect(1)

ax2=plt.subplot(222)
plt.hist(velocity(t_L1)[0],20, density=True, facecolor='purple',edgecolor='orange', alpha=1)
plt.xlabel("velocity,$\mu m/s$ ")
plt.ylabel("density")
#plt.xlim(12,15.5)

rft = np.fft.rfft(velocity(t_L1)[0])
rft[15:] = 0   # Note, rft.shape = 21
y_smooth = np.fft.irfft(rft)


####
ax3=plt.subplot(223)
plt.plot(np.arange(3600)/2,velocity(t_L1)[0],color='purple',alpha=0.5,linewidth=0.3)
plt.axhline(y=velocity(t_L1)[2], linewidth=2, color="orange",linestyle='dashed')
plt.plot( np.arange(3600)/2,y_smooth, label='Smoothed',color='black',alpha=1,linewidth=1)
plt.xlabel("$Time,s$")
plt.ylabel("velocity,$\mu m/s$ ")
#plt.xlim(12,15.5)

N=len(velocity(t_reference)[0])
sampling_rate =2
T = 1/sampling_rate 
x = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
yr = fft( velocity(t_L1)[0]) # "raw" FFT with both + and - frequencies
y = 2/N * np.abs(yr[0:np.int(N/2)]) # positive freqs only


ax3=plt.subplot(224)
plt.plot(x, y,color='black')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Vibration (g)')
plt.xlim(0,0.04)
plt.ylim(0,0.4)

#plt.xlim(12,15.5)
# Out:
# (0, 0.4)

# %%
plt.figure()
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.3)
ax1=plt.subplot(221)
plt.plot(t_3L2[['x']].values*scale,t_3L2[['y']].values*scale,color='purple',alpha=0.5,linewidth=0.3)
plt.xlabel("x($\mu m$) ")
plt.ylabel("y($\mu m$) ")
ax1.set_aspect(1)

ax2=plt.subplot(222)
plt.hist(velocity(t_3L2)[0],20, density=True, facecolor='purple',edgecolor='orange', alpha=1)
plt.xlabel("velocity,$\mu m/s$ ")
plt.ylabel("density")
#plt.xlim(12,15.5)
rft = np.fft.rfft(velocity(t_3L2)[0])
rft[15:] = 0   # Note, rft.shape = 21
y_smooth = np.fft.irfft(rft)
###
ax3=plt.subplot(223)
plt.plot(np.arange(2708)/2,velocity(t_3L2)[0],color='purple',alpha=0.5,linewidth=0.3)
plt.plot( np.arange(2708)/2,y_smooth, label='Smoothed',color='black',alpha=1,linewidth=1)
plt.axhline(y=velocity(t_3L2)[2], linewidth=2, color="orange",linestyle='dashed')
plt.xlabel("$Time,s$")
plt.ylabel("velocity,$\mu m/s$ ")
#plt.xlim(12,15.5)

N=len(velocity(t_3L2)[0])
sampling_rate =2
T = 1/sampling_rate 
x = np.linspace(0.0, 1.0/(2.0*T), int(N/2))
yr = fft( velocity(t_3L2)[0]) # "raw" FFT with both + and - frequencies
y = 2/N * np.abs(yr[0:np.int(N/2)]) # positive freqs only


ax3=plt.subplot(224)
plt.plot(x, y,color='black')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Vibration (g)')
plt.xlim(0,0.04)
plt.ylim(0,0.4)

#plt.xlim(12,15.5)
# Out:
# (0, 0.4)

# %%
plt.plot(velocity(t_3L2)[1])
plt.plot(velocity(t_3L1)[1])
plt.plot(velocity(t_L2)[1])
plt.plot(velocity(t_L1)[1])
plt.plot(velocity(t_reference)[1])

# %%
#plt.plot(net_reference)
#plt.plot(net)
#plt.plot(net_L2)
#plt.plot(net_3L1)
plt.plot(net_3L2)
plt.ylim(0,10)
plt.xlim(0,2000)
# Out:
# (0, 2000)

# %%
dx_dt = np.gradient(trac[:, 0])
dy_dt = np.gradient(trac[:, 1])
velocity = np.array([ [dx_dt[i], dy_dt[i]] for i in range(dx_dt.size)])

# %%
fps=1
scale=3600/1636
velocity_me=[]
for i in set(t1['particle'].values):
    
    net=np.linalg.norm(np.diff(t1.loc[t1['particle']==i][['x','y']].values,axis=0),axis=1)
    net2=[np.sum(net[:i]) for i in range(1,len(net))]
    #realframes=np.argmax(np.gradient(net2, 2)<0.09)
    #if  realframes==0:
       # realframes=t1['frame'].max()
    realframes=t1['frame'].max()
    distance=net2[-1]
    velocity_me.append(distance*scale/((realframes+1)/fps))

# %%
t1['frame'].max()
# Out:
# 179

# %%
t1.to_csv('electric.csv', encoding='utf-8')

# %%
np.mean(velocity_me)
np.std(velocity_me)
# Out:
# 1.914308372703426

# %%
np.mean(velocity_magnetic)
np.std(velocity_magnetic)
# Out:
# 0.6854351710047306

# %%
np.mean(velocity_electric)
np.std(velocity_electric)
# Out:
# 0.8325345893051683

# %%
import matplotlib
font = {'family' : 'normal',
       # 'weight' : 'normal',
        'size'   : 15}
matplotlib.rc('font', **font)
mean=np.array([np.mean(velocity_magnetic),np.mean(velocity_electric),np.mean(velocity_me)])*(3600/1636)
std=np.array([np.std(velocity_magnetic),np.std(velocity_electric),np.std(velocity_me)])*(3600/1636)
ind = ['magnetic','electric','magnetic+electric']
width = 0.4  
plt.bar(ind, mean, width, yerr=std, color=[(4/255,30/255,66/255)],ecolor=[(255/255,165/255,0)]\
        ,edgecolor=[(255/255,165/255,0)],linewidth=2)
plt.ylabel('velocity ''$\mu m/s$'' ',fontsize=20)
# Out:
# Text(0, 0.5, 'velocity $\\mu m/s$ ')
